# %% [markdown]
# <a href="https://colab.research.google.com/github/penny20051103-commits/programming/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
one=1

# %%
type(one)
# Out:
# int

# %%
two='abc'

# %%
type(two)
# Out:
# str

# %%
three=True

# %%
type(three)
# Out:
# bool

# %%
four=5.30

# %%
type(four)
# Out:
# float
